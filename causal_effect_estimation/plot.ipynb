# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
GAs = pd.read_csv("/mnt/disk1/aiotlab/hieupc/Arsenic_accumulation/causal_effect_estimation/DMAVAE/Res_Performance/Syn_DMAVAE_origin19.csv")

# %%
GAs['Temperature'] = np.linspace(22, 27 , 30)

# %%
plt.plot(GAs['Temperature'] , GAs['Grain.As'])
plt.xlabel("Temperature")
plt.ylabel("Grain.As")
plt.grid(True)
plt.show()

# %%
PE_intervention = pd.read_csv("/mnt/disk1/aiotlab/hieupc/Arsenic_accumulation/causal_effect_estimation/DMAVAE/Res_Performance/Syn_DMAVAE_origin19_PE.csv")

# %%
plt.plot(PE_intervention['PotentialEvaporation'] , PE_intervention['GrainAs'])
plt.xlabel("Potential.Evaporation")
plt.ylabel("Grain.As")
plt.grid(True)
plt.show()
